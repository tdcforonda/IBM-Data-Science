# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Thea Denisse C. Foronda** <br/>
# Artificial Intelligence Engineer

# %% [markdown]
# *I am interested in data science because I believe that the world is shifting towards a more data-driven and artificial intelligence centered community. I would love to be a part of a generation of engineers that allow computers to think on their own.*

# %% [markdown]
# ### The function below takes a list containing either odd or even numbers, except one. The code then finds which number is the outlier. For example, we enter a list of odd numbers with one number being even, the code then returns the even number. I made this code in CodeWars as practice for Python.

# %%
def find_outlier(integers):
    even = []
    even_numbers = 0
    odd = []
    odd_numbers = 0
    
    for number in integers:
        if number %2 == 0:
            even.append(number)
            even_numbers += 1
        elif number %2 == 1:
            odd.append(number)
            odd_numbers += 0
        
    if even_numbers == 1:
        return even[0]
    else:
        return odd[0]
    
print(find_outlier([160, 3, 1719, 19, 11, 13, -21]))
print(find_outlier([2, 4, 6, 8, 10, 3]))
# Out:
# 160
# 3

# %% [markdown]
# ## 🦭 Make sure to check out some of my accounts!
# 🐥 [Twitter](https://twitter.com/__fords) <br/>
# 📷 [Instagram](https://instagram.com/__fords) <br/>
# 💻 [GitHub](https://github.com/tdcforonda) <br/>
#
# ___
#
# ## 🙆🏻‍♀️ More about me
#
# > My current favorite subject is ~~Data Structure and Algorithms~~ any writing and language subject LOL. But along with that, here is a list of topics that I enjoy:
#
# <ul>
#     <li>Internet of Things</li>
#     <li>Deep Learning</li>
#     <li>CyberSecurity</li>
# </ul>
#
# > The reason why I prefer Artificial Intelligence over those topics is because:
#
# <ol>
#     <li>It's easier to prank people when a robot does it for you.</li>
#     <li>If all else fails, I can just make a Twitter prediction bot and get sponsors from my bot's humor alone.</li>
#     <li>I look up to Michael Reeves and I also want to make a robot that pees beer.</li>
# </ol>
#
# ___
#
# ## Some tools and languages that I like to work with:
#
# <table align="center">
#   <tr>
#     <td align="center" width="96">
#       <a>
#         <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/9/99/Unofficial_JavaScript_logo_2.svg/1024px-Unofficial_JavaScript_logo_2.svg.png" width="48" height="48" alt="JavaScript" />
#       </a>
#       <br>JavaScript
#     </td>
#     <td align="center" width="96">
#       <a>
#         <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/c/c3/Python-logo-notext.svg/1200px-Python-logo-notext.svg.png" width="48" height="48" alt="Python" />
#       </a>
#       <br>Python
#     </td>
#     <td align="center" width="96">
#       <a>
#         <img src="https://brandlogos.net/wp-content/uploads/2020/09/react-logo.png" width="48" height="48" alt="React" />
#       </a>
#       <br>React JS
#     </td>
#     <td align="center" width="96">
#       <a>
#         <img src="https://cdn.worldvectorlogo.com/logos/bootstrap-4.svg" width="48" height="48" alt="Bootstrap" />
#       </a>
#       <br>Bootstrap
#     </td>
#       <td align="center" width="96">
#       <a>
#         <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/1/18/ISO_C%2B%2B_Logo.svg/1200px-ISO_C%2B%2B_Logo.svg.png" width="48" height="48" alt="C++" />
#       </a>
#       <br>C++
#     </td>
#     <td align="center" width="96">
#       <a>
#         <img src="https://camo.githubusercontent.com/d7574156c7a1844d3c2907bae0e76254cca759290c08e08a6ef2bd7543c8c0ca/68747470733a2f2f692e6962622e636f2f737331374b47302f63376238313133323437666563643833626439623565643562643366333464352d72656d6f766562672d707265766965772e706e67" width="48" height="48" alt="Linux" />
#       </a>
#       <br>Linux
#     </td>
#   </tr>
#
#   <tr>
#     <td align="center" width="96">
#       <a>
#         <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/3/3f/Git_icon.svg/1200px-Git_icon.svg.png" width="48" height="48" alt="Git" />
#       </a>
#       <br>Git
#     </td>
#     <td align="center" width="96">
#       <a>
#         <img src="https://bashlogo.com/img/symbol/png/full_colored_dark.png" width="48" height="48" alt="Bash" />
#       </a>
#       <br>Bash
#     </td>
#     <td align="center" width="96">
#       <a>
#         <img src="https://upload.wikimedia.org/wikipedia/commons/3/33/Figma-logo.svg" width="45" height="45" alt="Figma" />
#       </a>
#       <br>Figma
#     </td>
#   </tr>
# </table>
#
# ___
#
#
# ## An explanation of my code above, in case you're interested.
#
# ***But first, here's a picture of a cat.***
# <img src = "https://images.unsplash.com/photo-1597626133663-53df9633b799?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=1160&q=80" alt = "cute cat" width="150">
#
#
# **Alright, here we go**
#
# 1. First, we define the function using `def function_name()`
# 2. Inside the function, we define two lists and two counters. The counters will serve as the "finder" of the outlier. Basically, whichever is equal to one, then that's the outlier "type", which is either odd or even.
#
# ```
# even = []
# even_numbers = 0
# odd = []
# odd_numbers = 0
# ```
#
# 3. We then create a `for loop` that iterates through the list and checks if each number is divisible to two. If it is, then we put it in the list of even numbers, and if it is not, then we put it in the list of odd numbers. Every time that we add something to either list, the counter for their type goes up to "count" how many of their type exists.
#
# ```
# for number in integers:
#         if number %2 == 0:
#             even.append(number)
#             even_numbers += 1
#         elif number %2 == 1:
#             odd.append(number)
#             odd_numbers += 0
# ```
#
# 4. Finally, we check which type has a count of exactly one number in the list. We then return the value of that outlier by accessing the first index of the list.
#
# ```
# if even_numbers == 1:
#         return even[0]
#     else:
#         return odd[0]
# ```
#
# And that's it for my Watson Studio Jupyter Notebook project! I hope you had fun reading my stuff!
